# %% [markdown]
# # 안녕하세요

# %% [markdown]
# ## 안녕하세요

# %% [markdown]
# ### 안녕하세요

# %% [markdown]
# 1. 안녕하세요
# 2. 안녕하세요
# 3. 안녕하세요

# %% [markdown]
# - 안녕하세요
# * 안녕하세요

# %% [markdown]
# ![하드웨어](./images/하드웨어.png)

# %% [markdown]
# <img src = './images/하드웨어.png' width = '300'>

# %%
print(globals())
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'print(globals())'], '_oh': {}, '_dh': [WindowsPath('c:/sj/1_python')], 'In': ['', 'print(globals())'], 'Out': {}, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001D0F24EB0B0>>, 'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x000001D0F397F710>, 'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x000001D0F397F710>, 'open': <function open at 0x000001D0F19FAFC0>, '_': '', '__': '', '___': '', '__vsc_ipynb_file__': 'c:\\sj\\1_python\\test.ipynb', '_i': '', '_ii': '', '_iii': '', '_i1': 'print(globals())'}
